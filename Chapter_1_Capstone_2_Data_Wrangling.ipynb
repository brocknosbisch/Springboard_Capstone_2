# %% [markdown]
#  # Capstone Project 2 - Data Wrangling
# ## Name: Brock Nosbisch
#
# #### Summary:
# This dataset contains summary level data for random cities.
# The data is read in through a csv (data.csv).
# I then set the index for the dataset to the unique identifier.
# Several fields needed to have their data types updated.
# Removed Pending Starts, Reactivated, and Cancelled SAs.
# Also removed a few bad records that had Null Rate Class, Company, Bill Cycle.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(color_codes=True)

# %%
# Function: print_counts
# Description: This function returns the Least Frequent and Most Frequent values of the field passed in.
#              We have hardcoded the df DataFrame.
# Valid values for parameters:
# dataframe = DataFrame
# field_name = name of field in the DF dataframe.
# sorting = asc or desc
# num = The number of records you want returned.
def print_counts(dataframe, field_name, sorting = 'asc', num = '5'):
    
    if sorting == 'asc':
        tmpSort = True
    else:
        tmpSort = False
        
    print(dataframe[field_name].value_counts(ascending=tmpSort).head(int(num)))
    
    return None

# %%
# Function: print_min_max
# Description: This function returns the Minimum or Maximum values of the field passed in.
#              We have hardcoded the df DataFrame.
# Valid values for parameters:
# dataframe = DataFrame
# field_name = name of field in the DF dataframe.
# min_max = min or max
# num = The number of records you want returned.
def print_min_max(dataframe, field_name, min_max = 'max', num = '5'):
    
    if min_max == 'max':
        tmpMinMax = False
    else:
        tmpMinMax = True

    print(dataframe[field_name].value_counts().to_frame().reset_index().sort_values('index', ascending=tmpMinMax).head(int(num)))
    
    return None

# %%
# Creation Functions Used.
def add_value_labels(ax, spacing=5):

    for rect in ax.patches:
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2

        space = spacing
        va = 'bottom'

        if y_value < 0:
            space *= -1
            # Vertical alignment
            va = 'top'

        label = "{:}".format(y_value)  # Use :.1f if wanting decimals.

        # Create annotation
        ax.annotate(label, (x_value, y_value), xytext=(0, space), textcoords="offset points", ha='center', va=va)

# %% [markdown]
# ## Load Data

# %%
file_name = 'data.csv' # Service Agreement Level

df=pd.DataFrame()

# Read in the file with new column names.
df = pd.read_csv(file_name, header=0)

df.set_index('SA_ID', inplace=True)

# %%
df.head(5)
# Out:
#              CIS_DIVISION   ACCOUNT_ID CUSTOMER_CLASS_CODE  \
# SA_ID
# 34935241500           LGC  11645080000                 RES
# 16293132432           MGE   5431044444                 RES
# 34937413572           MGE  11645804444                 RES
# 97756482240           LGC  32585493536                 RES
# 103835695332          LGC  34625440000                 RES
#
#              CUSTOMER_CLASS_DESCRIPTION    PERSON_ID SA_START_DATE  \
# SA_ID
# 34935241500                 Residential  62534880000     5/19/1993
# 16293132432                 Residential  33172328888     10/9/2014
# 34937413572                 Residential  19068248888      1/1/1969
# 97756482240                 Residential  28983386912      9/3/2013
# 103835695332                Residential  47351600000    10/16/2017
#
#               SA_START_YEAR  SA_START_YEAR_MONTH SA_END_DATE  SA_END_YEAR  \
# SA_ID
# 34935241500            1993               199305  12/31/2099         2099
# 16293132432            2014               201410  12/31/2099         2099
# 34937413572            1969               196901  12/31/2099         2099
# 97756482240            2013               201309  10/16/2017         2017
# 103835695332           2017               201710  12/31/2099         2099
#
#                      ...           PERSON_MIN_SA_END_DATE  \
# SA_ID                ...
# 34935241500          ...                              NaN
# 16293132432          ...                              NaN
# 34937413572          ...                              NaN
# 97756482240          ...                       10/16/2017
# 103835695332         ...                       10/22/2017
#
#               PREMISE_MAX_SA_START_DATE PREMISE_MIN_SA_START_DATE  \
# SA_ID
# 34935241500                   5/19/1993                 5/19/1993
# 16293132432                   10/9/2014                 10/9/2014
# 34937413572                    1/1/1969                  1/1/1969
# 97756482240                  10/16/2017                  9/3/2013
# 103835695332                 10/16/2017                  9/3/2013
#
#              PREMISE_MAX_SA_END_DATE PREMISE_MIN_SA_END_DATE  \
# SA_ID
# 34935241500                      NaN                     NaN
# 16293132432                      NaN                     NaN
# 34937413572                      NaN                     NaN
# 97756482240               10/16/2017              10/16/2017
# 103835695332              10/16/2017              10/16/2017
#
#               PREMISE_PRIOR_STOP_DATE PERSON_PRIOR_STOP_DATE  \
# SA_ID
# 34935241500                       NaN                    NaN
# 16293132432                       NaN                    NaN
# 34937413572                       NaN                    NaN
# 97756482240                       NaN                    NaN
# 103835695332               10/16/2017             10/22/2017
#
#              PREMISE_DAYS_INACTIVE_BEFORE  PERSON_DAYS_INACTIVE_BEFORE  \
# SA_ID
# 34935241500                             0                            0
# 16293132432                             0                            0
# 34937413572                             0                            0
# 97756482240                             0                            0
# 103835695332                            0                           -6
#
#              USAGE_PAST_18_MONTHS
# SA_ID
# 34935241500              1176.324
# 16293132432               952.000
# 34937413572               463.000
# 97756482240                 0.000
# 103835695332             1005.784
#
# [5 rows x 91 columns]

# %% [markdown]
# ## Update Data Types and Remove Unneeded/Bad Data

# %%
# Need to update data types.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709303 entries, 34935241500 to 68398773804
# Data columns (total 91 columns):
# CIS_DIVISION                     705120 non-null object
# ACCOUNT_ID                       709303 non-null int64
# CUSTOMER_CLASS_CODE              709303 non-null object
# CUSTOMER_CLASS_DESCRIPTION       709303 non-null object
# PERSON_ID                        709303 non-null int64
# SA_START_DATE                    709303 non-null object
# SA_START_YEAR                    709303 non-null int64
# SA_START_YEAR_MONTH              709303 non-null int64
# SA_END_DATE                      709303 non-null object
# SA_END_YEAR                      709303 non-null int64
# SA_END_YEAR_MONTH                709303 non-null int64
# SA_STATUS_FLAG                   709303 non-null int64
# SA_TYPE_CODE                     709303 non-null object
# RATE_CLASS_CODE                  708860 non-null object
# RATE_CLASS_DESCRIPTION           708860 non-null object
# PREMISE_ID                       709303 non-null int64
# CITY                             709303 non-null object
# STATE                            709303 non-null object
# POSTAL                           709303 non-null int64
# BILL_CYCLE_CODE                  703365 non-null object
# BILL_CYCLE_DESCRIPTION           703365 non-null object
# SERVICE_TYPE_CODE                709303 non-null object
# PREMISE_TYPE_CODE                709303 non-null object
# TREND_AREA_CODE                  709303 non-null object
# OFFICE_LOCATION                  709258 non-null object
# OFFICE_LOCATION_DESCRIPTION      709258 non-null object
# DNP_STARTED_FLAG                 359050 non-null object
# DNP_STOPPED_FLAG                 318238 non-null object
# INTERNAL_CREDIT_RATING           709303 non-null int64
# PREMISE_LEVEL_12_MTH_DNP_FLAG    709303 non-null object
# ACCOUNT_LEVEL_12_MTH_DNP_FLAG    709303 non-null object
# PERSON_RCVD_18_MTHS_PLEDGE       709303 non-null object
# PAYMENTS_IN_LAST_18_MONTHS       709303 non-null int64
# BILLS_IN_LAST_18_MONTHS          709303 non-null int64
# PAY_SEGS_IN_LAST_18_MONTHS       709303 non-null int64
# BILL_SEGS_IN_LAST_18_MONTHS      709303 non-null int64
# ARREARS_CURRENT_AMOUNT           709303 non-null float64
# ARREARS_PAYOFF_AMOUNT            709303 non-null float64
# TOTAL_CURRENT_AMOUNT             709303 non-null float64
# TOTAL_PAYOFF_AMOUNT              709303 non-null float64
# MOST_RECENT_PAYMENT_DATE         600114 non-null object
# LATE_PAYMENT_COUNT               709303 non-null int64
# SEASONAL_PRIOR_1_YR_FLAG         709303 non-null object
# SEASONAL_PRIOR_2_YR_FLAG         709303 non-null object
# SEASONAL_PRIOR_3_YR_FLAG         709303 non-null object
# SA_START_DEGREE_DAY              709303 non-null int64
# SA_START_AVG_TEMP                709303 non-null int64
# SA_END_DEGREE_DAY                709303 non-null int64
# SA_END_AVG_TEMP                  709303 non-null int64
# STOP_2013                        709303 non-null int64
# STOP_2014                        709303 non-null int64
# STOP_2015                        709303 non-null int64
# STOP_2016                        709303 non-null int64
# STOP_2017                        709303 non-null int64
# STOP_2018                        709303 non-null int64
# STOP_2019                        709303 non-null int64
# START_2013                       709303 non-null int64
# START_2014                       709303 non-null int64
# START_2015                       709303 non-null int64
# START_2016                       709303 non-null int64
# START_2017                       709303 non-null int64
# START_2018                       709303 non-null int64
# START_2019                       709303 non-null int64
# PLEDGE_DATE_2013                 0 non-null float64
# PLEDGE_FLAG_2013                 709303 non-null int64
# PLEDGE_DATE_2014                 0 non-null float64
# PLEDGE_FLAG_2014                 709303 non-null int64
# PLEDGE_DATE_2015                 4426 non-null object
# PLEDGE_FLAG_2015                 709303 non-null int64
# PLEDGE_DATE_2016                 5920 non-null object
# PLEDGE_FLAG_2016                 709303 non-null int64
# PLEDGE_DATE_2017                 5729 non-null object
# PLEDGE_FLAG_2017                 709303 non-null int64
# PLEDGE_DATE_2018                 3141 non-null object
# PLEDGE_FLAG_2018                 709303 non-null int64
# PLEDGE_DATE_2019                 0 non-null float64
# PLEDGE_FLAG_2019                 709303 non-null int64
# USAGE_IN_LAST_18_MONTHS          433226 non-null float64
# PERSON_MAX_SA_START_DATE         706652 non-null object
# PERSON_MIN_SA_START_DATE         706652 non-null object
# PERSON_MAX_SA_END_DATE           447148 non-null object
# PERSON_MIN_SA_END_DATE           447148 non-null object
# PREMISE_MAX_SA_START_DATE        707955 non-null object
# PREMISE_MIN_SA_START_DATE        707955 non-null object
# PREMISE_MAX_SA_END_DATE          506030 non-null object
# PREMISE_MIN_SA_END_DATE          506030 non-null object
# PREMISE_PRIOR_STOP_DATE          357821 non-null object
# PERSON_PRIOR_STOP_DATE           253651 non-null object
# PREMISE_DAYS_INACTIVE_BEFORE     709303 non-null int64
# PERSON_DAYS_INACTIVE_BEFORE      709303 non-null int64
# USAGE_PAST_18_MONTHS             709303 non-null float64
# dtypes: float64(9), int64(42), object(40)
# memory usage: 497.9+ MB

# %%
df = df.astype({'ACCOUNT_ID':'str', 
                'PERSON_ID':'str', 
                'SA_STATUS_FLAG':'str', 
                'PREMISE_ID':'str',
                'POSTAL':'str',
                'SA_START_YEAR':'str',
                'SA_START_YEAR_MONTH':'str',
                'SA_END_YEAR':'str',
                'SA_END_YEAR_MONTH':'str',
                'SA_START_DATE':'datetime64[ns]',
                'SA_END_DATE':'datetime64[ns]',
                'MOST_RECENT_PAYMENT_DATE':'datetime64[ns]',
                'PERSON_MAX_SA_START_DATE':'datetime64[ns]',
                'PERSON_MIN_SA_START_DATE':'datetime64[ns]',   
                'PERSON_MAX_SA_END_DATE':'datetime64[ns]',
                'PERSON_MIN_SA_END_DATE':'datetime64[ns]',
                'PREMISE_MAX_SA_START_DATE':'datetime64[ns]',
                'PREMISE_MIN_SA_START_DATE':'datetime64[ns]',
                'PREMISE_MAX_SA_END_DATE':'datetime64[ns]',
                'PREMISE_MIN_SA_END_DATE':'datetime64[ns]',
                'PREMISE_PRIOR_STOP_DATE':'datetime64[ns]',
                'PERSON_PRIOR_STOP_DATE':'datetime64[ns]',
                'PLEDGE_DATE_2013':'datetime64[ns]',
                'PLEDGE_DATE_2014':'datetime64[ns]',
                'PLEDGE_DATE_2015':'datetime64[ns]',
                'PLEDGE_DATE_2016':'datetime64[ns]',
                'PLEDGE_DATE_2017':'datetime64[ns]',
                'PLEDGE_DATE_2018':'datetime64[ns]',
                'PLEDGE_DATE_2019':'datetime64[ns]'
               })

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709303 entries, 34935241500 to 68398773804
# Data columns (total 91 columns):
# CIS_DIVISION                     705120 non-null object
# ACCOUNT_ID                       709303 non-null object
# CUSTOMER_CLASS_CODE              709303 non-null object
# CUSTOMER_CLASS_DESCRIPTION       709303 non-null object
# PERSON_ID                        709303 non-null object
# SA_START_DATE                    709303 non-null datetime64[ns]
# SA_START_YEAR                    709303 non-null object
# SA_START_YEAR_MONTH              709303 non-null object
# SA_END_DATE                      709303 non-null datetime64[ns]
# SA_END_YEAR                      709303 non-null object
# SA_END_YEAR_MONTH                709303 non-null object
# SA_STATUS_FLAG                   709303 non-null object
# SA_TYPE_CODE                     709303 non-null object
# RATE_CLASS_CODE                  708860 non-null object
# RATE_CLASS_DESCRIPTION           708860 non-null object
# PREMISE_ID                       709303 non-null object
# CITY                             709303 non-null object
# STATE                            709303 non-null object
# POSTAL                           709303 non-null object
# BILL_CYCLE_CODE                  703365 non-null object
# BILL_CYCLE_DESCRIPTION           703365 non-null object
# SERVICE_TYPE_CODE                709303 non-null object
# PREMISE_TYPE_CODE                709303 non-null object
# TREND_AREA_CODE                  709303 non-null object
# OFFICE_LOCATION                  709258 non-null object
# OFFICE_LOCATION_DESCRIPTION      709258 non-null object
# DNP_STARTED_FLAG                 359050 non-null object
# DNP_STOPPED_FLAG                 318238 non-null object
# INTERNAL_CREDIT_RATING           709303 non-null int64
# PREMISE_LEVEL_12_MTH_DNP_FLAG    709303 non-null object
# ACCOUNT_LEVEL_12_MTH_DNP_FLAG    709303 non-null object
# PERSON_RCVD_18_MTHS_PLEDGE       709303 non-null object
# PAYMENTS_IN_LAST_18_MONTHS       709303 non-null int64
# BILLS_IN_LAST_18_MONTHS          709303 non-null int64
# PAY_SEGS_IN_LAST_18_MONTHS       709303 non-null int64
# BILL_SEGS_IN_LAST_18_MONTHS      709303 non-null int64
# ARREARS_CURRENT_AMOUNT           709303 non-null float64
# ARREARS_PAYOFF_AMOUNT            709303 non-null float64
# TOTAL_CURRENT_AMOUNT             709303 non-null float64
# TOTAL_PAYOFF_AMOUNT              709303 non-null float64
# MOST_RECENT_PAYMENT_DATE         600114 non-null datetime64[ns]
# LATE_PAYMENT_COUNT               709303 non-null int64
# SEASONAL_PRIOR_1_YR_FLAG         709303 non-null object
# SEASONAL_PRIOR_2_YR_FLAG         709303 non-null object
# SEASONAL_PRIOR_3_YR_FLAG         709303 non-null object
# SA_START_DEGREE_DAY              709303 non-null int64
# SA_START_AVG_TEMP                709303 non-null int64
# SA_END_DEGREE_DAY                709303 non-null int64
# SA_END_AVG_TEMP                  709303 non-null int64
# STOP_2013                        709303 non-null int64
# STOP_2014                        709303 non-null int64
# STOP_2015                        709303 non-null int64
# STOP_2016                        709303 non-null int64
# STOP_2017                        709303 non-null int64
# STOP_2018                        709303 non-null int64
# STOP_2019                        709303 non-null int64
# START_2013                       709303 non-null int64
# START_2014                       709303 non-null int64
# START_2015                       709303 non-null int64
# START_2016                       709303 non-null int64
# START_2017                       709303 non-null int64
# START_2018                       709303 non-null int64
# START_2019                       709303 non-null int64
# PLEDGE_DATE_2013                 0 non-null datetime64[ns]
# PLEDGE_FLAG_2013                 709303 non-null int64
# PLEDGE_DATE_2014                 0 non-null datetime64[ns]
# PLEDGE_FLAG_2014                 709303 non-null int64
# PLEDGE_DATE_2015                 4426 non-null datetime64[ns]
# PLEDGE_FLAG_2015                 709303 non-null int64
# PLEDGE_DATE_2016                 5920 non-null datetime64[ns]
# PLEDGE_FLAG_2016                 709303 non-null int64
# PLEDGE_DATE_2017                 5729 non-null datetime64[ns]
# PLEDGE_FLAG_2017                 709303 non-null int64
# PLEDGE_DATE_2018                 3141 non-null datetime64[ns]
# PLEDGE_FLAG_2018                 709303 non-null int64
# PLEDGE_DATE_2019                 0 non-null datetime64[ns]
# PLEDGE_FLAG_2019                 709303 non-null int64
# USAGE_IN_LAST_18_MONTHS          433226 non-null float64
# PERSON_MAX_SA_START_DATE         706652 non-null datetime64[ns]
# PERSON_MIN_SA_START_DATE         706652 non-null datetime64[ns]
# PERSON_MAX_SA_END_DATE           447148 non-null datetime64[ns]
# PERSON_MIN_SA_END_DATE           447148 non-null datetime64[ns]
# PREMISE_MAX_SA_START_DATE        707955 non-null datetime64[ns]
# PREMISE_MIN_SA_START_DATE        707955 non-null datetime64[ns]
# PREMISE_MAX_SA_END_DATE          506030 non-null datetime64[ns]
# PREMISE_MIN_SA_END_DATE          506030 non-null datetime64[ns]
# PREMISE_PRIOR_STOP_DATE          357821 non-null datetime64[ns]
# PERSON_PRIOR_STOP_DATE           253651 non-null datetime64[ns]
# PREMISE_DAYS_INACTIVE_BEFORE     709303 non-null int64
# PERSON_DAYS_INACTIVE_BEFORE      709303 non-null int64
# USAGE_PAST_18_MONTHS             709303 non-null float64
# dtypes: datetime64[ns](20), float64(6), int64(33), object(32)
# memory usage: 497.9+ MB
# None

# %% [markdown]
# #### SA Status Flag Descriptions:
# * 10 - Pending Start
# * 20 - Active
# * 30 - Pending Stop
# * 40 - Stopped
# * 50 - Reactivated
# * 60 - Closed
# * 70 - Cancelled
#
# #### I will be removing the Cancelled SAs since they could have been cancelled for a number of reasons (ex. CSR mistake).  I will also be removing Reactivated since we don't deal with them much and all Pending Starts since we do not know what Division they are in yet.
# #### There is also 1 bad record that I am removing.

# %%
print ('Before: ')
print_counts(df, 'SA_STATUS_FLAG', 'desc','10')

df = (df[df['SA_STATUS_FLAG'] != '70']) # Cancelled SAs
df = (df[df['SA_STATUS_FLAG'] != '50']) # Reactivated SAs
df = (df[df['SA_STATUS_FLAG'] != '10']) # Pending Start SAs
df = (df[df['RATE_CLASS_CODE'].notnull()]) # Removing 1 bad record
df = (df[df['CIS_DIVISION'].notnull()]) # Removing bad records
df = (df[df['BILL_CYCLE_CODE'].notnull()]) # Removing bad records


print()
print()
print ('After: ')
print_counts(df, 'SA_STATUS_FLAG', 'desc','10')
# Out:
# Before:
# 20    334921
# 60    312015
# 70     45933
# 40     14345
# 30      1047
# 10       848
# 50       194
# Name: SA_STATUS_FLAG, dtype: int64
#
#
# After:
# 20    334917
# 60    311654
# 40     14339
# 30      1047
# Name: SA_STATUS_FLAG, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 661957 entries, 34935241500 to 68398773804
# Data columns (total 91 columns):
# CIS_DIVISION                     661957 non-null object
# ACCOUNT_ID                       661957 non-null object
# CUSTOMER_CLASS_CODE              661957 non-null object
# CUSTOMER_CLASS_DESCRIPTION       661957 non-null object
# PERSON_ID                        661957 non-null object
# SA_START_DATE                    661957 non-null datetime64[ns]
# SA_START_YEAR                    661957 non-null object
# SA_START_YEAR_MONTH              661957 non-null object
# SA_END_DATE                      661957 non-null datetime64[ns]
# SA_END_YEAR                      661957 non-null object
# SA_END_YEAR_MONTH                661957 non-null object
# SA_STATUS_FLAG                   661957 non-null object
# SA_TYPE_CODE                     661957 non-null object
# RATE_CLASS_CODE                  661957 non-null object
# RATE_CLASS_DESCRIPTION           661957 non-null object
# PREMISE_ID                       661957 non-null object
# CITY                             661957 non-null object
# STATE                            661957 non-null object
# POSTAL                           661957 non-null object
# BILL_CYCLE_CODE                  661957 non-null object
# BILL_CYCLE_DESCRIPTION           661957 non-null object
# SERVICE_TYPE_CODE                661957 non-null object
# PREMISE_TYPE_CODE                661957 non-null object
# TREND_AREA_CODE                  661957 non-null object
# OFFICE_LOCATION                  661920 non-null object
# OFFICE_LOCATION_DESCRIPTION      661920 non-null object
# DNP_STARTED_FLAG                 358537 non-null object
# DNP_STOPPED_FLAG                 318030 non-null object
# INTERNAL_CREDIT_RATING           661957 non-null int64
# PREMISE_LEVEL_12_MTH_DNP_FLAG    661957 non-null object
# ACCOUNT_LEVEL_12_MTH_DNP_FLAG    661957 non-null object
# PERSON_RCVD_18_MTHS_PLEDGE       661957 non-null object
# PAYMENTS_IN_LAST_18_MONTHS       661957 non-null int64
# BILLS_IN_LAST_18_MONTHS          661957 non-null int64
# PAY_SEGS_IN_LAST_18_MONTHS       661957 non-null int64
# BILL_SEGS_IN_LAST_18_MONTHS      661957 non-null int64
# ARREARS_CURRENT_AMOUNT           661957 non-null float64
# ARREARS_PAYOFF_AMOUNT            661957 non-null float64
# TOTAL_CURRENT_AMOUNT             661957 non-null float64
# TOTAL_PAYOFF_AMOUNT              661957 non-null float64
# MOST_RECENT_PAYMENT_DATE         599943 non-null datetime64[ns]
# LATE_PAYMENT_COUNT               661957 non-null int64
# SEASONAL_PRIOR_1_YR_FLAG         661957 non-null object
# SEASONAL_PRIOR_2_YR_FLAG         661957 non-null object
# SEASONAL_PRIOR_3_YR_FLAG         661957 non-null object
# SA_START_DEGREE_DAY              661957 non-null int64
# SA_START_AVG_TEMP                661957 non-null int64
# SA_END_DEGREE_DAY                661957 non-null int64
# SA_END_AVG_TEMP                  661957 non-null int64
# STOP_2013                        661957 non-null int64
# STOP_2014                        661957 non-null int64
# STOP_2015                        661957 non-null int64
# STOP_2016                        661957 non-null int64
# STOP_2017                        661957 non-null int64
# STOP_2018                        661957 non-null int64
# STOP_2019                        661957 non-null int64
# START_2013                       661957 non-null int64
# START_2014                       661957 non-null int64
# START_2015                       661957 non-null int64
# START_2016                       661957 non-null int64
# START_2017                       661957 non-null int64
# START_2018                       661957 non-null int64
# START_2019                       661957 non-null int64
# PLEDGE_DATE_2013                 0 non-null datetime64[ns]
# PLEDGE_FLAG_2013                 661957 non-null int64
# PLEDGE_DATE_2014                 0 non-null datetime64[ns]
# PLEDGE_FLAG_2014                 661957 non-null int64
# PLEDGE_DATE_2015                 4423 non-null datetime64[ns]
# PLEDGE_FLAG_2015                 661957 non-null int64
# PLEDGE_DATE_2016                 5913 non-null datetime64[ns]
# PLEDGE_FLAG_2016                 661957 non-null int64
# PLEDGE_DATE_2017                 5722 non-null datetime64[ns]
# PLEDGE_FLAG_2017                 661957 non-null int64
# PLEDGE_DATE_2018                 3137 non-null datetime64[ns]
# PLEDGE_FLAG_2018                 661957 non-null int64
# PLEDGE_DATE_2019                 0 non-null datetime64[ns]
# PLEDGE_FLAG_2019                 661957 non-null int64
# USAGE_IN_LAST_18_MONTHS          432355 non-null float64
# PERSON_MAX_SA_START_DATE         661957 non-null datetime64[ns]
# PERSON_MIN_SA_START_DATE         661957 non-null datetime64[ns]
# PERSON_MAX_SA_END_DATE           409685 non-null datetime64[ns]
# PERSON_MIN_SA_END_DATE           409685 non-null datetime64[ns]
# PREMISE_MAX_SA_START_DATE        661957 non-null datetime64[ns]
# PREMISE_MIN_SA_START_DATE        661957 non-null datetime64[ns]
# PREMISE_MAX_SA_END_DATE          463182 non-null datetime64[ns]
# PREMISE_MIN_SA_END_DATE          463182 non-null datetime64[ns]
# PREMISE_PRIOR_STOP_DATE          316269 non-null datetime64[ns]
# PERSON_PRIOR_STOP_DATE           217412 non-null datetime64[ns]
# PREMISE_DAYS_INACTIVE_BEFORE     661957 non-null int64
# PERSON_DAYS_INACTIVE_BEFORE      661957 non-null int64
# USAGE_PAST_18_MONTHS             661957 non-null float64
# dtypes: datetime64[ns](20), float64(6), int64(33), object(32)
# memory usage: 464.6+ MB

# %%
df.head(5)
# Out:
#              CIS_DIVISION   ACCOUNT_ID CUSTOMER_CLASS_CODE  \
# SA_ID
# 34935241500           LGC  11645080000                 RES
# 16293132432           MGE   5431044444                 RES
# 34937413572           MGE  11645804444                 RES
# 97756482240           LGC  32585493536                 RES
# 103835695332          LGC  34625440000                 RES
#
#              CUSTOMER_CLASS_DESCRIPTION    PERSON_ID SA_START_DATE  \
# SA_ID
# 34935241500                 Residential  62534880000    1993-05-19
# 16293132432                 Residential  33172328888    2014-10-09
# 34937413572                 Residential  19068248888    1969-01-01
# 97756482240                 Residential  28983386912    2013-09-03
# 103835695332                Residential  47351600000    2017-10-16
#
#              SA_START_YEAR SA_START_YEAR_MONTH SA_END_DATE SA_END_YEAR  \
# SA_ID
# 34935241500           1993              199305  2099-12-31        2099
# 16293132432           2014              201410  2099-12-31        2099
# 34937413572           1969              196901  2099-12-31        2099
# 97756482240           2013              201309  2017-10-16        2017
# 103835695332          2017              201710  2099-12-31        2099
#
#                      ...          PERSON_MIN_SA_END_DATE  \
# SA_ID                ...
# 34935241500          ...                             NaT
# 16293132432          ...                             NaT
# 34937413572          ...                             NaT
# 97756482240          ...                      2017-10-16
# 103835695332         ...                      2017-10-22
#
#              PREMISE_MAX_SA_START_DATE PREMISE_MIN_SA_START_DATE  \
# SA_ID
# 34935241500                 1993-05-19                1993-05-19
# 16293132432                 2014-10-09                2014-10-09
# 34937413572                 1969-01-01                1969-01-01
# 97756482240                 2017-10-16                2013-09-03
# 103835695332                2017-10-16                2013-09-03
#
#              PREMISE_MAX_SA_END_DATE PREMISE_MIN_SA_END_DATE  \
# SA_ID
# 34935241500                      NaT                     NaT
# 16293132432                      NaT                     NaT
# 34937413572                      NaT                     NaT
# 97756482240               2017-10-16              2017-10-16
# 103835695332              2017-10-16              2017-10-16
#
#              PREMISE_PRIOR_STOP_DATE PERSON_PRIOR_STOP_DATE  \
# SA_ID
# 34935241500                      NaT                    NaT
# 16293132432                      NaT                    NaT
# 34937413572                      NaT                    NaT
# 97756482240                      NaT                    NaT
# 103835695332              2017-10-16             2017-10-22
#
#              PREMISE_DAYS_INACTIVE_BEFORE PERSON_DAYS_INACTIVE_BEFORE  \
# SA_ID
# 34935241500                             0                           0
# 16293132432                             0                           0
# 34937413572                             0                           0
# 97756482240                             0                           0
# 103835695332                            0                          -6
#
#              USAGE_PAST_18_MONTHS
# SA_ID
# 34935241500              1176.324
# 16293132432               952.000
# 34937413572               463.000
# 97756482240                 0.000
# 103835695332             1005.784
#
# [5 rows x 91 columns]

# %%
df.describe()
# Out:
#        INTERNAL_CREDIT_RATING  PAYMENTS_IN_LAST_18_MONTHS  \
# count           661957.000000               661957.000000
# mean                98.139562                    8.147930
# std                333.794981                    7.958601
# min              -4262.000000                    0.000000
# 25%                 -1.000000                    0.000000
# 50%                 -1.000000                    6.000000
# 75%                 -1.000000                   18.000000
# max               2511.000000                  217.000000
#
#        BILLS_IN_LAST_18_MONTHS  PAY_SEGS_IN_LAST_18_MONTHS  \
# count            661957.000000               661957.000000
# mean                  9.348538                    8.147930
# std                   8.357426                    7.958601
# min                   0.000000                    0.000000
# 25%                   0.000000                    0.000000
# 50%                   9.000000                    6.000000
# 75%                  18.000000                   18.000000
# max                 164.000000                  217.000000
#
#        BILL_SEGS_IN_LAST_18_MONTHS  ARREARS_CURRENT_AMOUNT  \
# count                661957.000000           661957.000000
# mean                      9.348538               21.041593
# std                       8.357426              116.381483
# min                       0.000000           -23124.500000
# 25%                       0.000000                0.000000
# 50%                       9.000000                0.000000
# 75%                      18.000000               26.250000
# max                     164.000000            27252.750000
#
#        ARREARS_PAYOFF_AMOUNT  TOTAL_CURRENT_AMOUNT  TOTAL_PAYOFF_AMOUNT  \
# count          661957.000000         661957.000000        661957.000000
# mean               12.054118             21.403155            12.377496
# std               123.366641            115.895349           122.904606
# min            -23124.500000         -23124.500000        -23124.500000
# 25%                 0.000000              0.000000             0.000000
# 50%                 0.000000              0.000000             0.000000
# 75%                 7.190000             26.390000            10.490000
# max             27252.750000          27252.750000         27252.750000
#
#        LATE_PAYMENT_COUNT          ...           PLEDGE_FLAG_2014  \
# count       661957.000000          ...                   661957.0
# mean             0.657487          ...                        0.0
# std              2.341999          ...                        0.0
# min              0.000000          ...                        0.0
# 25%              0.000000          ...                        0.0
# 50%              0.000000          ...                        0.0
# 75%              0.000000          ...                        0.0
# max             18.000000          ...                        0.0
#
#        PLEDGE_FLAG_2015  PLEDGE_FLAG_2016  PLEDGE_FLAG_2017  PLEDGE_FLAG_2018  \
# count     661957.000000     661957.000000     661957.000000     661957.000000
# mean           0.006682          0.008933          0.008644          0.004739
# std            0.081468          0.094089          0.092571          0.068677
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        PLEDGE_FLAG_2019  USAGE_IN_LAST_18_MONTHS  \
# count          661957.0             4.323550e+05
# mean                0.0             1.504453e+03
# std                 0.0             4.831530e+04
# min                 0.0            -1.152780e+04
# 25%                 0.0             4.090000e+02
# 50%                 0.0             8.790000e+02
# 75%                 0.0             1.231000e+03
# max                 0.0             2.018102e+07
#
#        PREMISE_DAYS_INACTIVE_BEFORE  PERSON_DAYS_INACTIVE_BEFORE  \
# count                 661957.000000                661957.000000
# mean                   -1271.078943                 -2080.937652
# std                     6099.024596                  7712.977248
# min                   -39660.000000                -51013.000000
# 25%                        0.000000                     0.000000
# 50%                        0.000000                     0.000000
# 75%                        0.000000                     0.000000
# max                     7465.000000                  7683.000000
#
#        USAGE_PAST_18_MONTHS
# count          6.619570e+05
# mean           9.826283e+02
# std            3.905376e+04
# min           -1.152780e+04
# 25%            0.000000e+00
# 50%            3.636000e+02
# 75%            1.032947e+03
# max            2.018102e+07
#
# [8 rows x 39 columns]

# %% [markdown]
# ### Write data to file to use in Data Story

# %%
filename = 'data_wrangling_out.csv'
df.to_csv(filename)

# %% [markdown]
# ### ANNEX

# %%
tmp=1000994193*8
tmp=str(tmp)
df.loc[(df['PERSON_ID']==tmp)]
# Out:
#             CIS_DIVISION   ACCOUNT_ID CUSTOMER_CLASS_CODE  \
# SA_ID
# 41359068480          MGE  13791730408                 RES
# 41325819840          MGE  13791730408                 RES
#
#             CUSTOMER_CLASS_DESCRIPTION   PERSON_ID SA_START_DATE  \
# SA_ID
# 41359068480                Residential  8007953544    2018-03-05
# 41325819840                Residential  8007953544    2017-03-08
#
#             SA_START_YEAR SA_START_YEAR_MONTH SA_END_DATE SA_END_YEAR  \
# SA_ID
# 41359068480          2018              201803  2099-12-31        2099
# 41325819840          2017              201703  2017-12-27        2017
#
#                     ...          PERSON_MIN_SA_END_DATE  \
# SA_ID               ...
# 41359068480         ...                      2017-12-27
# 41325819840         ...                      2017-12-27
#
#             PREMISE_MAX_SA_START_DATE PREMISE_MIN_SA_START_DATE  \
# SA_ID
# 41359068480                2018-03-05                2014-11-24
# 41325819840                2019-01-14                2014-08-27
#
#             PREMISE_MAX_SA_END_DATE PREMISE_MIN_SA_END_DATE  \
# SA_ID
# 41359068480              2018-03-05              2015-09-07
# 41325819840              2019-01-14              2016-12-05
#
#             PREMISE_PRIOR_STOP_DATE PERSON_PRIOR_STOP_DATE  \
# SA_ID
# 41359068480              2018-03-05             2017-12-27
# 41325819840              2017-03-08                    NaT
#
#             PREMISE_DAYS_INACTIVE_BEFORE PERSON_DAYS_INACTIVE_BEFORE  \
# SA_ID
# 41359068480                            0                          68
# 41325819840                            0                           0
#
#             USAGE_PAST_18_MONTHS
# SA_ID
# 41359068480                527.0
# 41325819840                  0.0
#
# [2 rows x 91 columns]
